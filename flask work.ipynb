# %%
# SQL Alchemy
from sqlalchemy import create_engine
from sqlalchemy.ext.automap import automap_base

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()

# %%
engine = create_engine("mysql://root:Primavera01@localhost/simpsons")

#user:pass@host:port/schema

# %%
data = engine.execute("select * from characters")

# %%
for record in data:
    print(record)
# Out:
# (1, 'Marge Simpson', 'marge simpson', 'f', 'True')
# (2, 'Homer Simpson', 'homer simpson', 'm', 'True')
# (3, 'Seymour Skinner', 'seymour skinner', 'm', 'False')
# (4, 'JANEY', 'janey', 'f', 'False')
# (5, 'Todd Flanders', 'todd flanders', 'm', 'False')
# (6, 'Dewey Largo', 'dewey largo', 'm', 'False')
# (7, 'Children', 'children', 'u', 'False')
# (8, 'Bart Simpson', 'bart simpson', 'm', 'True')
# (9, 'Lisa Simpson', 'lisa simpson', 'f', 'True')
# (10, 'Patty Bouvier', 'patty bouvier', 'f', 'False')
# (11, 'Ned Flanders', 'ned flanders', 'm', 'False')
# (12, 'Mechanical Santa', 'mechanical santa', 'm', 'False')
# (13, 'Tattoo Man', 'tattoo man', 'm', 'False')
# (14, 'Waylon Smithers', 'waylon smithers', 'm', 'False')
# (15, 'C. Montgomery Burns', 'c montgomery burns', 'm', 'False')
# (16, 'DOCTOR ZITSOFSKY', 'doctor zitsofsky', 'u', 'False')
# (17, 'Moe Szyslak', 'moe szyslak', 'm', 'False')
# (18, 'Barney Gumble', 'barney gumble', 'm', 'False')
# (19, 'Interviewer', 'interviewer', 'm', 'False')
# (20, 'Students', 'students', 'u', 'False')
# (21, 'Teacher', 'teacher', 'm', 'False')
# (22, 'Selma Bouvier', 'selma bouvier', 'f', 'False')
# (23, 'Voice', 'voice', 'm', 'False')
# (24, 'Little Boy', 'little boy', 'm', 'False')
# (25, 'Milhouse Van Houten', 'milhouse van houten', 'm', 'False')
# (26, 'Lewis Clark', 'lewis clark', 'm', 'False')
# (27, 'Little Girl', 'little girl', 'f', 'False')
# (28, 'Clerk', 'clerk', 'm', 'False')
# (29, 'Bubbles', 'bubbles', 'u', 'False')
# (30, 'Moldy', 'moldy', 'u', 'False')
# (31, 'Grampa Simpson', 'grampa simpson', 'm', 'False')
# (32, 'Father', 'father', 'm', 'False')
# (33, 'Announcer', 'announcer', 'm', 'False')
# (34, 'Ticket Seller', 'ticket seller', 'u', 'False')
# (35, 'Elf #1', 'elf 1', 'u', 'False')
# (36, 'Elves', 'elves', 'u', 'False')
# (37, "Dog's Owner", 'dogs owner', 'u', 'False')
# (38, 'Martin Prince', 'martin prince', 'm', 'False')
# (39, 'Kids', 'kids', 'u', 'False')
# (40, 'Edna Krabappel-Flanders', 'edna krabappel-flanders', 'f', 'False')
# (41, 'Conductor', 'conductor', 'u', 'False')
# (42, 'Secretary', 'secretary', 'u', 'False')
# (43, 'Dr. J. Loren Pyror', 'dr j loren pyror', 'm', 'False')
# (44, 'Ms. Melon', 'ms melon', 'f', 'False')
# (45, 'Ethan Foley', 'ethan foley', 'm', 'False')
# (46, 'Sydney', 'sydney', 'u', 'False')
# (47, 'Cecile Shapiro', 'cecile shapiro', 'u', 'False')
# (48, 'Ian', 'ian', 'm', 'False')
# (49, 'Calvin', 'calvin', 'm', 'False')
# (50, 'Martin Prince, Sr.', 'martin prince sr', 'm', 'False')
# (51, 'Richard', 'richard', 'm', 'False')
# (52, 'Otto Mann', 'otto mann', 'm', 'False')
# (53, 'Wendell Borton', 'wendell borton', 'm', 'False')
# (54, 'Sherri Mackleberry', 'sherri mackleberry', 'f', 'False')
# (55, 'Terri Mackleberry', 'terri mackleberry', 'f', 'False')
# (56, 'Narrator', 'narrator', 'm', 'False')
# (57, "Smilin' Joe Fission", 'smilin joe fission', 'm', 'False')
# (58, 'Rod #1', 'rod 1', 'u', 'False')
# (59, 'Rod #2', 'rod 2', 'u', 'False')
# (60, 'RODS', 'rods', 'u', 'False')
# (61, 'Workman #1', 'workman 1', 'u', 'False')
# (62, 'Foreman', 'foreman', 'u', 'False')
# (63, 'TERRI & SHERRI', 'terri sherri', 'f', 'False')
# (64, 'PUNK TEENAGER', 'punk teenager', 'u', 'False')
# (65, 'Tv Announcer #1', 'tv announcer 1', 'u', 'False')
# (66, 'Tv Announcer #2', 'tv announcer 2', 'u', 'False')
# (67, 'Jingle Chorus', 'jingle chorus', 'u', 'False')
# (68, 'Sylvia Winfield', 'sylvia winfield', 'f', 'False')
# (69, 'Old Man Winfield', 'old man winfield', 'm', 'False')
# (70, 'Councilman #1', 'councilman 1', 'u', 'False')
# (71, 'Chief Wiggum', 'chief wiggum', 'm', 'False')
# (72, 'Councilman #2', 'councilman 2', 'u', 'False')
# (73, 'COUNCILMEN #1/#2', 'councilmen 12', 'u', 'False')
# (74, 'Demonstrator #1', 'demonstrator 1', 'u', 'False')
# (75, 'Crowd', 'crowd', 'u', 'False')
# (76, 'MR. GAMMILL', 'mr gammill', 'm', 'False')
# (77, 'TOM', 'tom', 'm', 'False')
# (78, 'Mrs. Long', 'mrs long', 'f', 'False')
# (79, 'Wife #1', 'wife 1', 'f', 'False')
# (80, 'Wife #2', 'wife 2', 'f', 'False')
# (81, 'Other Women', 'other women', 'f', 'False')
# (82, 'Nice Father', 'nice father', 'm', 'False')
# (83, 'Nice Boy', 'nice boy', 'm', 'False')
# (84, 'NICE GIRL', 'nice girl', 'f', 'False')
# (85, 'Nice Mother', 'nice mother', 'f', 'False')
# (86, 'NICE FAMILY', 'nice family', 'u', 'False')
# (87, 'Williams Boy', 'williams boy', 'm', 'False')
# (88, 'Mr. Williams', 'mr williams', 'm', 'False')
# (89, 'BOXING ANNOUNCER', 'boxing announcer', 'u', 'False')
# (90, 'Eddie', 'eddie', 'm', 'False')
# (91, 'Lou', 'lou', 'm', 'False')
# (92, 'TV-STATION ANNOUNCER', 'tv-station announcer', 'u', 'False')
# (93, 'Tv Wife', 'tv wife', 'f', 'False')
# (94, 'Tv Husband', 'tv husband', 'm', 'False')
# (95, 'Small Boy', 'small boy', 'm', 'False')
# (96, 'Dr. Marvin Monroe', 'dr marvin monroe', 'm', 'False')
# (97, 'Pawn Broker', 'pawn broker', 'u', 'False')
# (98, 'Receptionist', 'receptionist', 'f', 'False')
# (99, 'Homer-ish Husband', 'homer-ish husband', 'm', 'False')
# (100, 'Weasel #1', 'weasel 1', 'u', 'False')
# (101, 'Nelson Muntz', 'nelson muntz', 'm', 'False')
# (102, 'ALL AT THE TABLE', 'all at the table', 'u', 'False')
# (103, 'Kid', 'kid', 'u', 'False')
# (104, 'Weasel #2', 'weasel 2', 'u', 'False')
# (105, 'Maggie Simpson', 'maggie simpson', 'f', 'True')
# (106, "Homer's Image", 'homers image', 'm', 'True')
# (107, 'Elderly Gentleman', 'elderly gentleman', 'm', 'False')
# (108, 'Herman Hermann', 'herman hermann', 'm', 'False')
# (109, 'All', 'all', 'u', 'False')
# (110, 'Ms. Barr', 'ms barr', 'f', 'False')
# (111, 'Bleeding Gums Murphy', 'bleeding gums murphy', 'm', 'False')
# (112, 'Jacqueline Bouvier', 'jacqueline bouvier', 'f', 'False')
# (113, 'Newsman', 'newsman', 'm', 'False')
# (114, 'Barflies', 'barflies', 'u', 'False')
# (115, 'Cashier', 'cashier', 'm', 'False')
# (116, 'Boy Onlooker', 'boy onlooker', 'm', 'False')
# (117, 'Champ', 'champ', 'u', 'False')
# (118, 'Woman', 'woman', 'f', 'False')
# (119, 'Ralph Wiggum', 'ralph wiggum', 'm', 'False')
# (120, 'Stan', 'stan', 'm', 'False')
# (121, 'Rod Flanders', 'rod flanders', 'm', 'False')
# (122, 'NED', 'ned', 'm', 'False')
# (123, 'Cowboy Bob', 'cowboy bob', 'm', 'False')
# (124, 'Salesman', 'salesman', 'm', 'False')
# (125, "Homer's Canyon Echo", 'homers canyon echo', 'm', 'True')
# (126, 'Camper Father', 'camper father', 'm', 'False')
# (127, 'Camper Mother', 'camper mother', 'f', 'False')
# (128, 'Photographer', 'photographer', 'u', 'False')
# (129, 'Game Warden', 'game warden', 'u', 'False')
# (130, 'Reporter #1', 'reporter 1', 'u', 'False')
# (131, 'Reporter #2', 'reporter 2', 'u', 'False')
# (132, 'Flunky', 'flunky', 'u', 'False')
# (133, 'Map Boy', 'map boy', 'm', 'False')
# (134, 'Man #1', 'man 1', 'm', 'False')
# (135, 'Man #2', 'man 2', 'm', 'False')
# (136, 'German Scientist', 'german scientist', 'm', 'False')
# (137, 'Beautiful French Scientist', 'beautiful french scientist', 'f', 'False')
# (138, 'English Scientist', 'english scientist', 'u', 'False')
# (139, 'Krusty the Clown', 'krusty the clown', 'm', 'False')
# (140, 'Rev. Timothy Lovejoy', 'rev timothy lovejoy', 'm', 'False')
# (141, 'Announcer #1', 'announcer 1', 'u', 'False')
# (142, 'Radio Announcer #1', 'radio announcer 1', 'u', 'False')
# (143, 'Churchgoing Woman', 'churchgoing woman', 'f', 'False')
# (144, 'Jimbo Jones', 'jimbo jones', 'm', 'False')
# (145, 'Kearney Zzyzwicz', 'kearney zzyzwicz', 'm', 'False')
# (146, 'DOLPH', 'dolph', 'm', 'False')
# (147, 'Girl On Screen', 'girl on screen', 'f', 'False')
# (148, 'Boy On Screen', 'boy on screen', 'm', 'False')
# (149, 'Usher', 'usher', 'u', 'False')
# (150, 'Mr. Dandy', 'mr dandy', 'm', 'False')
# (151, 'Radio Announcer #3', 'radio announcer 3', 'u', 'False')
# (152, 'Jebediah Springfield', 'jebediah springfield', 'm', 'False')
# (153, 'Sideshow Bob', 'sideshow bob', 'm', 'False')
# (154, "TV ANNOUNCER #3 CONT'D", 'tv announcer 3 contd', 'u', 'False')
# (155, 'Mob', 'mob', 'u', 'False')
# (156, 'Security Guard', 'security guard', 'm', 'False')
# (157, 'Waiters', 'waiters', 'u', 'False')
# (158, '1st Waiter Quartet', '1st waiter quartet', 'u', 'False')
# (159, '2nd Waiter Quartet', '2nd waiter quartet', 'u', 'False')
# (160, '3rd Waiter Quartet', '3rd waiter quartet', 'u', 'False')
# (161, '4TH QUARTET OF WAITERS', '4th quartet of waiters', 'u', 'False')
# (162, 'Counter Guy', 'counter guy', 'm', 'False')
# (163, 'Jacques', 'jacques', 'm', 'False')
# (164, 'HELEN', 'helen', 'f', 'False')
# (165, 'Lenny Leonard', 'lenny leonard', 'm', 'False')
# (166, 'Another Worker', 'another worker', 'u', 'False')
# (167, 'Female Mail Carrier', 'female mail carrier', 'f', 'False')
# (168, 'Mr. Fisk', 'mr fisk', 'm', 'False')
# (169, 'Eugene Fisk', 'eugene fisk', 'm', 'False')
# (170, 'Carl Carlson', 'carl carlson', 'm', 'False')
# (171, 'Waiter', 'waiter', 'm', 'False')
# (172, 'Workers', 'workers', 'u', 'False')
# (173, 'Princess Kashmir', 'princess kashmir', 'f', 'False')
# (174, 'Hoyt', 'hoyt', 'm', 'False')
# (175, 'Girl #1', 'girl 1', 'f', 'False')
# (176, 'Boy #1', 'boy 1', 'm', 'False')
# (177, 'All Kids', 'all kids', 'u', 'False')
# (178, 'Freddie', 'freddie', 'm', 'False')
# (179, "Lewis's Dad", 'lewiss dad', 'm', 'False')
# (180, 'Al', 'al', 'm', 'False')
# (181, 'Happy Man', 'happy man', 'm', 'False')
# (182, 'Funky Guy', 'funky guy', 'm', 'False')
# (183, 'Manager', 'manager', 'm', 'False')
# (184, 'Man At Door', 'man at door', 'm', 'False')
# (185, 'Ticket-seller', 'ticket-seller', 'u', 'False')
# (186, 'Stage Manager', 'stage manager', 'u', 'False')
# (187, 'Gulliver Dark', 'gulliver dark', 'm', 'False')
# (188, 'Theatre-goer #1', 'theatre-goer 1', 'u', 'False')
# (189, 'Theatre-goer #2', 'theatre-goer 2', 'u', 'False')
# (190, 'Theatre-goer #3', 'theatre-goer 3', 'u', 'False')
# (191, 'Krusty Doll', 'krusty doll', 'm', 'False')
# (192, 'Agnes Skinner', 'agnes skinner', 'f', 'False')
# (193, 'Steward', 'steward', 'm', 'False')
# (194, 'Mother', 'mother', 'f', 'False')
# (195, 'Adil Hoxha', 'adil hoxha', 'u', 'False')
# (196, 'UGOLIN', 'ugolin', 'u', 'False')
# (197, 'Cesar', 'cesar', 'm', 'False')
# (198, 'Male Announcer', 'male announcer', 'm', 'False')
# (199, 'Military Man', 'military man', 'm', 'False')
# (200, 'MARGE & BART', 'marge bart', 'u', 'True')
# (201, 'Gendarme', 'gendarme', 'u', 'False')
# (202, 'Cia Agent #1', 'cia agent 1', 'u', 'False')
# (203, 'Cia Agent #2', 'cia agent 2', 'u', 'False')
# (204, 'Brad', 'brad', 'm', 'False')
# (205, 'Female Announcer', 'female announcer', 'f', 'False')
# (206, 'Brittany', 'brittany', 'f', 'False')
# (207, 'ITCHY & SCRATCHY CHORUS', 'itchy scratchy chorus', 'u', 'False')
# (208, 'Apu Nahasapeemapetilon', 'apu nahasapeemapetilon', 'm', 'False')
# (209, 'Police Artist', 'police artist', 'u', 'False')
# (210, 'Scott Christian', 'scott christian', 'm', 'False')
# (211, 'Kent Brockman', 'kent brockman', 'm', 'False')
# (212, 'Reporter #3', 'reporter 3', 'u', 'False')
# (213, 'Lawyer', 'lawyer', 'm', 'False')
# (214, 'Judge Snyder', 'judge snyder', 'm', 'False')
# (215, 'District Attorney', 'district attorney', 'u', 'False')
# (216, 'Merchant', 'merchant', 'u', 'False')
# (217, 'Foreperson', 'foreperson', 'u', 'False')
# (218, 'Director', 'director', 'm', 'False')
# (219, 'Merchandiser #1', 'merchandiser 1', 'u', 'False')
# (220, 'Merchandiser #3', 'merchandiser 3', 'u', 'False')
# (221, 'Kbbl Weatherman', 'kbbl weatherman', 'u', 'False')
# (222, 'Arnie Pye', 'arnie pye', 'm', 'False')
# (223, 'Radio Announcer', 'radio announcer', 'm', 'False')
# (224, 'Screener', 'screener', 'u', 'False')
# (225, 'Worker One', 'worker one', 'u', 'False')
# (226, 'Florist', 'florist', 'u', 'False')
# (227, 'Lucille Botzcowski', 'lucille botzcowski', 'f', 'False')
# (228, "Maitre D'", 'maitre d', 'u', 'False')
# (229, 'Doofy', 'doofy', 'u', 'False')
# (230, 'U-Squeal Operator', 'u-squeal operator', 'u', 'False')
# (231, 'Tv Reporter', 'tv reporter', 'u', 'False')
# (233, "Bart's Voice", 'barts voice', 'm', 'True')
# (234, "Krabappel's Mouth", 'krabappels mouth', 'f', 'False')
# (235, 'GRANDMA', 'grandma', 'f', 'False')
# (236, 'Nurse Farrell', 'nurse farrell', 'f', 'False')
# (237, 'Nurse', 'nurse', 'f', 'False')
# (238, 'Marty', 'marty', 'm', 'False')
# (239, 'Bill', 'bill', 'm', 'False')
# (240, 'Mayor Joe Quimby', 'mayor joe quimby', 'm', 'False')
# (241, 'Entire Town', 'entire town', 'u', 'False')
# (242, 'Thomas Jefferson', 'thomas jefferson', 'm', 'False')
# (243, 'John Adams', 'john adams', 'm', 'False')
# (244, 'Samuel Chase', 'samuel chase', 'm', 'False')
# (245, 'Roger Sherman', 'roger sherman', 'm', 'False')
# (246, 'Benjamin Franklin', 'benjamin franklin', 'm', 'False')
# (247, 'Tv Host', 'tv host', 'u', 'False')
# (248, 'Tv Contestant', 'tv contestant', 'u', 'False')
# (249, 'Good-looking Man', 'good-looking man', 'm', 'False')
# (250, 'Dr. H. Boyle', 'dr h boyle', 'u', 'False')
# (251, 'Mr. Winfield', 'mr winfield', 'm', 'False')
# (252, 'Mourners', 'mourners', 'u', 'False')
# (253, 'Other Runner', 'other runner', 'u', 'False')
# (254, 'Jake', 'jake', 'm', 'False')
# (255, 'Woman Applicant', 'woman applicant', 'f', 'False')
# (256, 'Karl', 'karl', 'm', 'False')
# (257, 'Man In Tuxedo', 'man in tuxedo', 'm', 'False')
# (258, 'Executive #1', 'executive 1', 'u', 'False')
# (259, 'Executive #3', 'executive 3', 'u', 'False')
# (260, 'Moving Man', 'moving man', 'm', 'False')
# (261, 'House', 'house', 'u', 'False')
# (262, 'Kang', 'kang', 'm', 'False')
# (263, 'Serak The Preparer', 'serak the preparer', 'm', 'False')
# (264, 'Kodos', 'kodos', 'm', 'False')
# (265, 'V.O.', 'vo', 'u', 'False')
# (266, 'Raven', 'raven', 'u', 'False')
# (267, 'Dave Shutton', 'dave shutton', 'm', 'False')
# (268, 'Chief Inspector', 'chief inspector', 'u', 'False')
# (269, 'Dean Danielson', 'dean danielson', 'm', 'False')
# (270, 'DANIELSON', 'danielson', 'm', 'False')
# (271, 'DANEILSON', 'daneilson', 'u', 'False')
# (272, 'TV Announcer', 'tv announcer', 'm', 'False')
# (273, 'Jasper Beardly', 'jasper beardly', 'm', 'False')
# (274, 'OLD BEARDED GUY', 'old bearded guy', 'm', 'False')
# (275, 'Charles Darwin', 'charles darwin', 'm', 'False')
# (276, 'Singers', 'singers', 'u', 'False')
# (277, 'MARY BAILEY', 'mary bailey', 'f', 'False')
# (278, 'Investigator #1', 'investigator 1', 'u', 'False')
# (279, 'Investigator #2', 'investigator 2', 'u', 'False')
# (280, 'Investigator #3', 'investigator 3', 'u', 'False')
# (281, 'Make-up Man', 'make-up man', 'm', 'False')
# (282, 'Gregor', 'gregor', 'm', 'False')
# (283, 'GAMMILL', 'gammill', 'u', 'False')
# (284, 'FLASH', 'flash', 'u', 'False')
# (285, 'Player #1', 'player 1', 'u', 'False')
# (286, 'P.A. Announcer', 'pa announcer', 'u', 'False')
# (288, 'Dan Hoard', 'dan hoard', 'm', 'False')
# (289, 'Vendor', 'vendor', 'u', 'False')
# (290, 'VENDER', 'vender', 'u', 'False')
# (291, "MR. O'HARA", 'mr ohara', 'm', 'False')
# (292, 'Man On Bus', 'man on bus', 'm', 'False')
# (293, 'Player #2', 'player 2', 'u', 'False')
# (294, 'Rasta #1', 'rasta 1', 'u', 'False')
# (295, 'Rasta #2', 'rasta 2', 'u', 'False')
# (296, 'Supervisor', 'supervisor', 'u', 'False')
# (297, 'Tony Bennett', 'tony bennett', 'm', 'False')
# (298, 'Capital City Goofball', 'capital city goofball', 'm', 'False')
# (299, 'Dave Glass', 'dave glass', 'm', 'False')
# (300, 'First Wife #3', 'first wife 3', 'f', 'False')
# (301, 'First Wife #1', 'first wife 1', 'f', 'False')
# (302, 'Hot Dog Man', 'hot dog man', 'm', 'False')
# (303, 'Spectator #1', 'spectator 1', 'u', 'False')
# (304, 'Spectator #2', 'spectator 2', 'u', 'False')
# (305, 'Spectator #3', 'spectator 3', 'u', 'False')
# (306, 'Clubhouse Attendant', 'clubhouse attendant', 'u', 'False')
# (307, 'Dave Rosenfield', 'dave rosenfield', 'm', 'False')
# (308, 'Maude Flanders', 'maude flanders', 'f', 'False')
# (309, 'Helen Lovejoy', 'helen lovejoy', 'f', 'False')
# (310, 'Librarian', 'librarian', 'u', 'False')
# (311, 'Man', 'man', 'm', 'False')
# (312, 'SENIOR CITIZENS', 'senior citizens', 'u', 'False')
# (313, 'British Commentator', 'british commentator', 'm', 'False')
# (314, 'Announcer #2', 'announcer 2', 'u', 'False')
# (315, 'Mrs. Spencer', 'mrs spencer', 'f', 'False')
# (316, 'Security Guard #1', 'security guard 1', 'u', 'False')
# (317, 'Casey', 'casey', 'u', 'False')
# (318, 'Rory', 'rory', 'm', 'False')
# (319, 'Transient', 'transient', 'u', 'False')
# (320, 'Uncle Sam', 'uncle sam', 'm', 'False')
# (321, 'Audience', 'audience', 'u', 'False')
# (322, 'Tv Voice #1', 'tv voice 1', 'u', 'False')
# (323, 'Tv Voice #2', 'tv voice 2', 'u', 'False')
# (324, 'Tv Voice #3', 'tv voice 3', 'u', 'False')
# (325, 'ALL THREE TV VOICES', 'all three tv voices', 'u', 'False')
# (326, 'ALL 3 ANNOUNCERS', 'all 3 announcers', 'u', 'False')
# (327, 'LARGO', 'largo', 'm', 'False')
# (328, 'SCRAPER', 'scraper', 'u', 'False')
# (329, 'CLARK', 'clark', 'm', 'False')
# (330, 'Track Announcer', 'track announcer', 'm', 'False')
# (331, 'MURDOCK', 'murdock', 'm', 'False')
# (332, 'Dr. Julius Hibbert', 'dr julius hibbert', 'm', 'False')
# (333, 'SMYTHE', 'smythe', 'm', 'False')
# (334, 'Itchy & Scratchy Singers', 'itchy scratchy singers', 'u', 'False')
# (335, 'Roger Meyers, Jr.', 'roger meyers jr', 'm', 'False')
# (336, 'Her Group', 'her group', 'u', 'False')
# (337, 'Animator', 'animator', 'u', 'False')
# (338, '1ST BOARD MEMBER', '1st board member', 'u', 'False')
# (339, '2nd Board Member', '2nd board member', 'u', 'False')
# (340, 'Squirrel', 'squirrel', 'u', 'False')
# (342, 'Scratchy', 'scratchy', 'm', 'False')
# (343, 'Itchy', 'itchy', 'm', 'False')
# (344, 'Curator', 'curator', 'u', 'False')
# (345, 'Reporter', 'reporter', 'm', 'False')
# (346, 'Devil', 'devil', 'm', 'False')
# (347, 'Lionel Hutz', 'lionel hutz', 'm', 'False')
# (348, 'Della', 'della', 'f', 'False')
# (349, 'Dr. Nick Riviera', 'dr nick riviera', 'm', 'False')
# (350, 'Bailiff', 'bailiff', 'u', 'False')
# (351, 'Blue-Haired Lawyer', 'blue-haired lawyer', 'm', 'False')
# (352, 'BURNS LAWYER', 'burns lawyer', 'u', 'False')
# (353, 'Larry', 'larry', 'm', 'False')
# (354, 'Sushi Bar Chefs', 'sushi bar chefs', 'u', 'False')
# (355, 'Hostess', 'hostess', 'f', 'False')
# (356, 'Akira', 'akira', 'm', 'False')
# (357, 'Toshiro', 'toshiro', 'm', 'False')
# (358, 'Master', 'master', 'm', 'False')
# (359, 'Richie Sakai', 'richie sakai', 'm', 'False')
# (360, 'Cellmate', 'cellmate', 'u', 'False')
# (361, 'Crazy Calls', 'crazy calls', 'u', 'False')
# (362, 'Smitty', 'smitty', 'm', 'False')
# (363, 'Larry King', 'larry king', 'm', 'False')
# (364, 'LARRY KING V.O.', 'larry king vo', 'm', 'False')
# (365, 'Bald One', 'bald one', 'm', 'False')
# (366, 'Police Captain', 'police captain', 'u', 'False')
# (368, 'Fat One', 'fat one', 'u', 'False')
# (369, 'Kim', 'kim', 'f', 'False')
# (370, 'Principal Dondelinger', 'principal dondelinger', 'm', 'False')
# (371, 'Estelle', 'estelle', 'f', 'False')
# (372, 'MCINTYRE', 'mcintyre', 'm', 'False')
# (373, 'Artie Ziff', 'artie ziff', 'm', 'False')
# (374, 'Mrs. Bloominstein', 'mrs bloominstein', 'f', 'False')
# (375, 'Coach Flanagan', 'coach flanagan', 'm', 'False')
# (376, 'Mr. Seckofsky', 'mr seckofsky', 'm', 'False')
# (377, 'Mr. Bouvier', 'mr bouvier', 'm', 'False')
# (378, 'Chauffeur', 'chauffeur', 'u', 'False')
# (379, 'PRINCIPAL', 'principal', 'u', 'False')
# (380, 'Homer The Thief', 'homer the thief', 'm', 'True')
# (381, 'Hezron', 'hezron', 'm', 'False')
# (382, 'Zohar', 'zohar', 'm', 'False')
# (383, 'Moses', 'moses', 'm', 'False')
# (384, 'Cable Guy', 'cable guy', 'm', 'False')
# (385, 'Comic', 'comic', 'm', 'False')
# (386, 'Woman #1', 'woman 1', 'f', 'False')
# (387, 'Woman #2', 'woman 2', 'f', 'False')
# (388, 'Mexican Announcer', 'mexican announcer', 'u', 'False')
# (389, 'Representative', 'representative', 'u', 'False')
# (390, 'Cockfight Announcer', 'cockfight announcer', 'u', 'False')
# (391, 'Davey', 'davey', 'm', 'False')
# (392, 'Goliath', 'goliath', 'm', 'False')
# (394, 'Panelist #1', 'panelist 1', 'u', 'False')
# (395, 'Blockbuster Announcer', 'blockbuster announcer', 'u', 'False')
# (396, 'Top Hat Announcer', 'top hat announcer', 'u', 'False')
# (397, 'Stock Reporter', 'stock reporter', 'u', 'False')
# (398, 'Boxing Announcer #1', 'boxing announcer 1', 'u', 'False')
# (399, 'Boxing Announcer #2', 'boxing announcer 2', 'u', 'False')
# (400, 'Challenger', 'challenger', 'u', 'False')
# (401, 'Referee', 'referee', 'u', 'False')
# (402, 'Kindly Old Gent', 'kindly old gent', 'm', 'False')
# (403, 'Stanley', 'stanley', 'm', 'False')
# (404, 'Groundskeeper Willie', 'groundskeeper willie', 'm', 'False')
# (405, 'Busboy', 'busboy', 'm', 'False')
# (406, 'Australian Boy', 'australian boy', 'm', 'False')
# (407, 'Australian Girl', 'australian girl', 'f', 'False')
# (408, 'Jeweler', 'jeweler', 'u', 'False')
# (409, 'Senator Mendoza', 'senator mendoza', 'm', 'False')
# (410, 'Board Member', 'board member', 'u', 'False')
# (411, 'Female Commando', 'female commando', 'f', 'False')
# (412, 'Theatre Manager', 'theatre manager', 'u', 'False')
# (413, 'Floozy', 'floozy', 'f', 'False')
# (414, 'Mona Simpson', 'mona simpson', 'f', 'False')
# (416, 'Attendant', 'attendant', 'u', 'False')
# (417, 'HERB', 'herb', 'm', 'False')
# (418, 'Policeman', 'policeman', 'u', 'False')
# (419, 'Executive #2', 'executive 2', 'u', 'False')
# (420, 'Head Engineer', 'head engineer', 'u', 'False')
# (421, 'Engineer #2', 'engineer 2', 'u', 'False')
# (422, 'Engineer #3', 'engineer 3', 'u', 'False')
# (423, 'Female Singer', 'female singer', 'f', 'False')
# (424, 'Counter Man', 'counter man', 'm', 'False')
# (425, "Flanders's Thoughts", 'flanderss thoughts', 'm', 'False')
# (426, 'Troy McClure', 'troy mcclure', 'm', 'False')
# (427, 'Emily', 'emily', 'f', 'False')
# (428, 'Kelly', 'kelly', 'f', 'False')
# (429, 'Jack', 'jack', 'm', 'False')
# (430, 'Father McGrath', 'father mcgrath', 'm', 'False')
# (431, 'Salesboy', 'salesboy', 'm', 'False')
# (432, 'Hula Woman', 'hula woman', 'f', 'False')
# (433, 'Farmer', 'farmer', 'm', 'False')
# (434, 'BEA', 'bea', 'f', 'False')
# (435, 'Checker', 'checker', 'u', 'False')
# (436, 'Guard', 'guard', 'm', 'False')
# (437, 'Tracker', 'tracker', 'u', 'False')
# (438, 'Mr. Hazelwood', 'mr hazelwood', 'm', 'False')
# (439, 'Cabbie', 'cabbie', 'u', 'False')
# (440, 'KENT', 'kent', 'm', 'False')
# (441, 'MONROE', 'monroe', 'm', 'False')
# (442, 'Professor Jonathan Frink', 'professor jonathan frink', 'm', 'False')
# (443, 'Old Man Daly', 'old man daly', 'm', 'False')
# (444, 'Old Man McGrath', 'old man mcgrath', 'm', 'False')
# (445, 'Plato', 'plato', 'm', 'False')
# (446, 'Croupier', 'croupier', 'u', 'False')
# (447, 'Recorded Announcer', 'recorded announcer', 'u', 'False')
# (448, 'Old Woman In Line', 'old woman in line', 'f', 'False')
# (449, 'Monitor #1', 'monitor 1', 'u', 'False')
# (450, 'Monitor #2', 'monitor 2', 'u', 'False')
# (451, 'Female Newscaster', 'female newscaster', 'f', 'False')
# (452, 'Mr. Schindler', 'mr schindler', 'm', 'False')
# (453, 'Student', 'student', 'u', 'False')
# (454, 'Registrar', 'registrar', 'u', 'False')
# (455, 'Professor Lombardo', 'professor lombardo', 'u', 'False')
# (456, 'BART & LISA', 'bart lisa', 'u', 'True')
# (457, 'Artist', 'artist', 'u', 'False')
# (458, 'Delivery Man', 'delivery man', 'm', 'False')
# (459, "MR. BURNS' GEOMETRIC SHAPES", 'mr burns geometric shapes', 'm', 'False')
# (460, 'RINGO', 'ringo', 'm', 'False')
# (461, 'WETHERBY', 'wetherby', 'm', 'False')
# (462, 'MRS. HOOVER', 'mrs hoover', 'f', 'False')
# (463, 'Chuck', 'chuck', 'm', 'False')
# (464, 'Miss Hoover', 'miss hoover', 'f', 'False')
# (465, 'BERGSTROM', 'bergstrom', 'm', 'False')
# (466, 'Classmate', 'classmate', 'u', 'False')
# (467, 'Terri/sherri', 'terrisherri', 'f', 'False')
# (468, 'Woman In Booth', 'woman in booth', 'f', 'False')
# (469, 'Landlady', 'landlady', 'f', 'False')
# (470, 'Kid Reporter', 'kid reporter', 'u', 'False')
# (471, "Husband Of Marge's Friend", 'husband of marges friend', 'm', 'False')
# (472, 'Sophisticate #1', 'sophisticate 1', 'u', 'False')
# (473, 'Sophisticate #2', 'sophisticate 2', 'u', 'False')
# (474, 'Sophisticate #3', 'sophisticate 3', 'u', 'False')
# (475, 'Sultan', 'sultan', 'u', 'False')
# (476, 'Worm Man', 'worm man', 'm', 'False')
# (477, 'Gloria', 'gloria', 'f', 'False')
# (478, 'John', 'john', 'm', 'False')
# (479, 'Captain', 'captain', 'm', 'False')
# (480, 'Convict', 'convict', 'u', 'False')
# (481, 'Customer', 'customer', 'u', 'False')
# (482, 'DIAMOND JOE', 'diamond joe', 'm', 'False')
# (483, 'Lost And Found Guy', 'lost and found guy', 'm', 'False')
# (484, 'Radioactive Man', 'radioactive man', 'm', 'False')
# (485, 'Fallout Boy', 'fallout boy', 'm', 'False')
# (486, 'Convention Director', 'convention director', 'u', 'False')
# (487, 'BUDDY', 'buddy', 'm', 'False')
# (488, 'Dealer', 'dealer', 'u', 'False')
# (489, 'Young Patty', 'young patty', 'f', 'False')
# (490, 'Young Selma', 'young selma', 'f', 'False')
# (492, 'Older Patty', 'older patty', 'f', 'False')
# (493, 'Older Selma', 'older selma', 'f', 'False')
# (494, 'Adult Narrator', 'adult narrator', 'u', 'False')
# (495, 'Teller', 'teller', 'u', 'False')
# (496, 'Mrs. Glick', 'mrs glick', 'f', 'False')
# (497, 'Asa', 'asa', 'm', 'False')
# (498, 'Soap Actress', 'soap actress', 'f', 'False')
# (499, 'Soap Actor', 'soap actor', 'm', 'False')
# (500, 'Osvaldo', 'osvaldo', 'm', 'False')
# (501, 'Mail Person', 'mail person', 'u', 'False')
# (502, 'Roman', 'roman', 'u', 'False')
# (503, 'Postal Worker', 'postal worker', 'u', 'False')
# (505, 'Joey', 'joey', 'm', 'False')
# (506, 'Guard #1', 'guard 1', 'u', 'False')
# (507, 'Guard #2', 'guard 2', 'u', 'False')
# (508, 'Host', 'host', 'm', 'False')
# (509, 'Psychiatrist', 'psychiatrist', 'u', 'False')
# (510, 'Orderly', 'orderly', 'u', 'False')
# (511, 'MICHAEL', 'michael', 'm', 'False')
# (512, 'Floyd', 'floyd', 'm', 'False')
# (513, "Bart's Head", 'barts head', 'm', 'True')
# (514, 'Wiseguy', 'wiseguy', 'm', 'False')
# (515, 'Voice On Phone', 'voice on phone', 'u', 'False')
# (516, 'Doctor', 'doctor', 'm', 'False')
# (517, 'Dave', 'dave', 'm', 'False')
# (518, 'Snake Jailbird', 'snake jailbird', 'm', 'False')
# (519, 'Leon Kompowsky', 'leon kompowsky', 'm', 'False')
# (520, 'Minnesota Girl', 'minnesota girl', 'f', 'False')
# (521, 'Alabama Boy', 'alabama boy', 'm', 'False')
# (522, 'QUEENS BOY', 'queens boy', 'm', 'False')
# (523, 'Female Judge', 'female judge', 'f', 'False')
# (524, 'Dad', 'dad', 'm', 'False')
# (525, 'Flight Attendant', 'flight attendant', 'u', 'False')
# (526, 'Pilot', 'pilot', 'm', 'False')
# (527, 'Irs Man', 'irs man', 'm', 'False')
# (528, 'Hotel Guest', 'hotel guest', 'u', 'False')
# (529, 'Miss Crowley', 'miss crowley', 'f', 'False')
# (530, 'Truong/maria', 'truongmaria', 'u', 'False')
# (531, 'TRUONG', 'truong', 'm', 'False')
# (532, 'MARIA', 'maria', 'f', 'False')
# (533, 'BARBARA', 'barbara', 'f', 'False')
# (534, 'Worker', 'worker', 'u', 'False')
# (535, 'Guide', 'guide', 'u', 'False')
# (536, 'Lobbyist', 'lobbyist', 'u', 'False')
# (537, 'Arnold', 'arnold', 'm', 'False')
# (538, 'Newlywed Wife', 'newlywed wife', 'f', 'False')
# (539, 'White Trash Woman #1', 'white trash woman 1', 'f', 'False')
# (540, 'Man #3', 'man 3', 'u', 'False')
# (541, 'Old Timer', 'old timer', 'u', 'False')
# (542, 'Guy', 'guy', 'm', 'False')
# (543, 'Songster', 'songster', 'u', 'False')
# (544, 'Page', 'page', 'u', 'False')
# (545, 'Senator', 'senator', 'u', 'False')
# (546, 'Oil Developer', 'oil developer', 'u', 'False')
# (547, 'Agent', 'agent', 'u', 'False')
# (548, 'Speaker', 'speaker', 'u', 'False')
# (549, 'Majority Leader', 'majority leader', 'u', 'False')
# (550, 'Everyone Else', 'everyone else', 'u', 'False')
# (551, 'President', 'president', 'm', 'False')
# (552, 'Foreign Dignitary', 'foreign dignitary', 'u', 'False')
# (553, 'Paper Boy', 'paper boy', 'm', 'False')
# (554, 'Sportscaster #1', 'sportscaster 1', 'u', 'False')
# (555, 'Girl', 'girl', 'f', 'False')
# (556, 'Neighborhood Guy', 'neighborhood guy', 'm', 'False')
# (557, 'Homemaker', 'homemaker', 'u', 'False')
# (558, 'Landscaper', 'landscaper', 'u', 'False')
# (559, 'Choreographer', 'choreographer', 'u', 'False')
# (560, 'George Washington', 'george washington', 'm', 'False')
# (561, 'Video Voice', 'video voice', 'u', 'False')
# (562, 'Man Shopper', 'man shopper', 'm', 'False')
# (563, "HOMER (CONT'D", 'homer contd', 'm', 'True')
# (564, 'Collection Agent', 'collection agent', 'u', 'False')
# (565, 'Wife', 'wife', 'f', 'False')
# (566, 'Shoppers', 'shoppers', 'u', 'False')
# (567, 'Executive', 'executive', 'm', 'False')
# (568, 'Fat Tony', 'fat tony', 'm', 'False')
# (569, 'Legs', 'legs', 'u', 'False')
# (570, 'Louie', 'louie', 'm', 'False')
# (571, 'Race Announcer', 'race announcer', 'u', 'False')
# (572, 'Jack Larson', 'jack larson', 'm', 'False')
# (573, 'Fbi Agent #1', 'fbi agent 1', 'u', 'False')
# (574, 'Fbi Agent #2', 'fbi agent 2', 'u', 'False')
# (575, 'Rival Gang Leader', 'rival gang leader', 'm', 'False')
# (576, 'Psychic', 'psychic', 'f', 'False')
# (577, 'Skinner Body', 'skinner body', 'm', 'False')
# (578, 'Prosecuting Attorney', 'prosecuting attorney', 'u', 'False')
# (579, 'Joe', 'joe', 'm', 'False')
# (580, 'Neil', 'neil', 'm', 'False')
# (581, 'Calm Woman', 'calm woman', 'f', 'False')
# (582, 'Mr. Devereaux', 'mr devereaux', 'm', 'False')
# (583, 'Margarita', 'margarita', 'f', 'False')
# (584, 'Program Voices', 'program voices', 'u', 'False')
# (585, 'Instructor', 'instructor', 'm', 'False')
# (586, 'Female Worker', 'female worker', 'f', 'False')
# (587, 'Male Worker', 'male worker', 'm', 'False')
# (588, 'Contestant', 'contestant', 'u', 'False')
# (589, 'Magic Johnson', 'magic johnson', 'm', 'False')
# (590, 'Aristotle', 'aristotle', 'm', 'False')
# (591, 'Luann Van Houten', 'luann van houten', 'f', 'False')
# (592, 'Thought Bubble Barney', 'thought bubble barney', 'm', 'False')
# (593, 'Female Voice', 'female voice', 'f', 'False')
# (594, 'SCOTT', 'scott', 'm', 'False')
# (595, 'Miss Lois Pennycandy', 'miss lois pennycandy', 'f', 'False')
# (596, 'Sexy Female Recording', 'sexy female recording', 'f', 'False')
# (597, 'PENNYCANDY', 'pennycandy', 'f', 'False')
# (598, 'Rabbi Hyman Krustofsky', 'rabbi hyman krustofsky', 'm', 'False')
# (600, 'Rabbi #1', 'rabbi 1', 'm', 'False')
# (601, 'Rowdy Rabbi', 'rowdy rabbi', 'm', 'False')
# (602, 'Martian', 'martian', 'u', 'False')
# (603, 'D.J.', 'dj', 'm', 'False')
# (604, 'Caller', 'caller', 'u', 'False')
# (605, 'MONSIGNOR DALEY', 'monsignor daley', 'm', 'False')
# (606, 'Yiddle', 'yiddle', 'u', 'False')
# (607, 'Rabbi #2', 'rabbi 2', 'm', 'False')
# (608, 'Waitress', 'waitress', 'f', 'False')
# (609, 'Stagehand', 'stagehand', 'u', 'False')
# (610, 'Airport Announcer', 'airport announcer', 'u', 'False')
# (611, 'Customs Agent', 'customs agent', 'u', 'False')
# (612, 'Military Cops', 'military cops', 'u', 'False')
# (613, 'English Diplomat', 'english diplomat', 'u', 'False')
# (614, 'Argentine Diplomat', 'argentine diplomat', 'u', 'False')
# (615, 'Colonel', 'colonel', 'm', 'False')
# (616, 'Female Office Worker', 'female office worker', 'f', 'False')
# (617, 'Male Office Worker', 'male office worker', 'm', 'False')
# (618, 'Townspeople', 'townspeople', 'u', 'False')
# (619, 'Patrons', 'patrons', 'u', 'False')
# (620, 'Vin Scully', 'vin scully', 'm', 'False')
# (621, 'Kids In Audience', 'kids in audience', 'u', 'False')
# (622, 'DR MONROE', 'dr monroe', 'm', 'False')
# (623, 'Crypt Keeper Willie', 'crypt keeper willie', 'm', 'False')
# (624, 'Robot', 'robot', 'u', 'False')
# (625, 'Homer-Ape', 'homer-ape', 'm', 'True')
# (626, 'Lunchlady Doris', 'lunchlady doris', 'f', 'False')
# (627, 'Little Man', 'little man', 'm', 'False')
# (628, 'Teenager', 'teenager', 'u', 'False')
# (630, 'Baby Lisa', 'baby lisa', 'f', 'True')
# (631, 'Salesclerk', 'salesclerk', 'u', 'False')
# (632, 'Millicent', 'millicent', 'f', 'False')
# (633, 'Female Clerk', 'female clerk', 'f', 'False')
# (634, 'Kevin', 'kevin', 'u', 'False')
# (635, 'Johnny Carson', 'johnny carson', 'm', 'False')
# (636, 'Scoey', 'scoey', 'm', 'False')
# (637, 'Teenage Clerk', 'teenage clerk', 'u', 'False')
# (638, 'Football Announcer', 'football announcer', 'm', 'False')
# (639, 'DAVE JR.', 'dave jr', 'm', 'False')
# (640, 'Official', 'official', 'u', 'False')
# (641, 'Voice From Trunk', 'voice from trunk', 'u', 'False')
# (642, 'Ronnie', 'ronnie', 'm', 'False')
# (643, 'DREDERICK', 'drederick', 'm', 'False')
# (644, 'Wanda', 'wanda', 'f', 'False')
# (645, 'Becky', 'becky', 'f', 'False')
# (646, 'Girls', 'girls', 'f', 'False')
# (647, 'Patron #1', 'patron 1', 'u', 'False')
# (648, 'Patron #2', 'patron 2', 'u', 'False')
# (649, 'Collette', 'collette', 'f', 'False')
# (650, 'HARV', 'harv', 'm', 'False')
# (651, 'Bernard', 'bernard', 'm', 'False')
# (652, 'Aide', 'aide', 'm', 'False')
# (653, 'Aerosmith', 'aerosmith', 'm', 'False')
# (654, 'Steven Tyler', 'steven tyler', 'm', 'False')
# (655, 'Joe Perry', 'joe perry', 'm', 'False')
# (656, 'Brad Whitford', 'brad whitford', 'm', 'False')
# (657, 'HUGH', 'hugh', 'm', 'False')
# (658, 'Everyone', 'everyone', 'u', 'False')
# (659, 'Bartender', 'bartender', 'u', 'False')
# (660, 'One-eyed Bartender', 'one-eyed bartender', 'u', 'False')
# (661, 'Flowers', 'flowers', 'u', 'False')
# (662, 'Tom Hamilton', 'tom hamilton', 'm', 'False')
# (663, 'Joey Kramer', 'joey kramer', 'm', 'False')
# (664, 'Snappy', 'snappy', 'u', 'False')
# (665, 'Broker', 'broker', 'u', 'False')
# (666, 'Hans', 'hans', 'm', 'False')
# (667, 'Fritz', 'fritz', 'm', 'False')
# (668, 'Charlie', 'charlie', 'm', 'False')
# (669, 'Horst', 'horst', 'm', 'False')
# (670, 'German Teacher', 'german teacher', 'm', 'False')
# (671, 'Boxer', 'boxer', 'u', 'False')
# (672, 'Mr. Thorson', 'mr thorson', 'm', 'False')
# (673, 'Angel', 'angel', 'u', 'False')
# (674, 'Patient', 'patient', 'u', 'False')
# (675, 'Justice Of The Peace', 'justice of the peace', 'u', 'False')
# (676, 'Groom', 'groom', 'm', 'False')
# (677, 'Applicant #1', 'applicant 1', 'u', 'False')
# (678, 'Applicant #2', 'applicant 2', 'u', 'False')
# (679, 'Applicants', 'applicants', 'u', 'False')
# (680, 'Tourist Kid', 'tourist kid', 'u', 'False')
# (681, 'Tourist Dad', 'tourist dad', 'm', 'False')
# (682, 'Boss', 'boss', 'u', 'False')
# (683, 'Elderly Lady', 'elderly lady', 'f', 'False')
# (684, 'Repo Man', 'repo man', 'm', 'False')
# (685, 'Driver', 'driver', 'u', 'False')
# (686, 'M.C.', 'mc', 'u', 'False')
# (687, 'Boy', 'boy', 'u', 'False')
# (688, 'Operator', 'operator', 'u', 'False')
# (689, 'Barber', 'barber', 'u', 'False')
# (690, 'Rosarita', 'rosarita', 'u', 'False')
# (691, 'Weasel', 'weasel', 'u', 'False')
# (692, 'Robot Weasel', 'robot weasel', 'u', 'False')
# (693, 'Señor Beaver-otti', 'señor beaver-otti', 'u', 'False')
# (694, 'Robot Animals', 'robot animals', 'u', 'False')
# (695, 'Fat Cop', 'fat cop', 'u', 'False')
# (696, 'Falcon Man', 'falcon man', 'm', 'False')
# (697, 'Sailor', 'sailor', 'u', 'False')
# (698, 'Sting', 'sting', 'm', 'False')
# (699, 'Sideshow Mel', 'sideshow mel', 'm', 'False')
# (700, 'Choir', 'choir', 'u', 'False')
# (701, 'Souvenir Hawker', 'souvenir hawker', 'u', 'False')
# (702, 'Station Announcer', 'station announcer', 'u', 'False')
# (703, 'Old Lady #1', 'old lady 1', 'f', 'False')
# (704, 'Bret', 'bret', 'm', 'False')
# (705, 'JIMMY', 'jimmy', 'm', 'False')
# (706, 'Sportscaster', 'sportscaster', 'u', 'False')
# (707, 'Coach', 'coach', 'u', 'False')
# (708, 'Football Announcer #2', 'football announcer 2', 'u', 'False')
# (709, 'Player', 'player', 'u', 'False')
# (710, 'Marco', 'marco', 'm', 'False')
# (711, 'Box', 'box', 'u', 'False')
# (712, 'Nutty Comedian', 'nutty comedian', 'u', 'False')
# (713, 'Alien', 'alien', 'u', 'False')
# (714, 'Duff Announcer', 'duff announcer', 'u', 'False')
# (715, 'Nick', 'nick', 'm', 'False')
# (716, 'Nick #2', 'nick 2', 'm', 'False')
# (717, 'Commercial Guy', 'commercial guy', 'm', 'False')
# (718, 'Man On Phone', 'man on phone', 'm', 'False')
# (719, 'Bus Driver', 'bus driver', 'u', 'False')
# (720, 'Policewoman', 'policewoman', 'f', 'False')
# (721, 'Different Announcer', 'different announcer', 'u', 'False')
# (722, 'Chef Rodrigo', 'chef rodrigo', 'u', 'False')
# (723, 'Gregory', 'gregory', 'm', 'False')
# (724, 'FABRIZIO', 'fabrizio', 'u', 'False')
# (725, 'Woman On Tv #1', 'woman on tv 1', 'f', 'False')
# (726, 'Woman On Tv #2', 'woman on tv 2', 'f', 'False')
# (727, 'Teenage Boy', 'teenage boy', 'm', 'False')
# (728, 'CHIF WIGGUM', 'chif wiggum', 'm', 'False')
# (729, 'Service Manager', 'service manager', 'u', 'False')
# (730, 'Ted', 'ted', 'm', 'False')
# (731, 'Sound-alikes', 'sound-alikes', 'u', 'False')
# (732, 'Mister Amazing', 'mister amazing', 'm', 'False')
# (733, 'Sparkle', 'sparkle', 'f', 'False')
# (734, 'Romantic Lover Voice', 'romantic lover voice', 'u', 'False')
# (735, 'Southern Private', 'southern private', 'u', 'False')
# (736, 'Charles Boyer', 'charles boyer', 'm', 'False')
# (737, 'Umpire', 'umpire', 'u', 'False')
# (738, 'Dispatcher', 'dispatcher', 'u', 'False')
# (739, 'ARI', 'ari', 'm', 'False')
# (740, 'Jose Canseco', 'jose canseco', 'm', 'False')
# (741, 'Mike Scioscia', 'mike scioscia', 'm', 'False')
# (742, 'Tour Guide', 'tour guide', 'm', 'False')
# (743, 'Ozzie Smith', 'ozzie smith', 'm', 'False')
# (744, 'Don Mattingly', 'don mattingly', 'm', 'False')
# (745, 'Steve Sax', 'steve sax', 'm', 'False')
# (746, 'Roger Clemens', 'roger clemens', 'm', 'False')
# (747, 'Wade Boggs', 'wade boggs', 'm', 'False')
# (748, 'KEN GRIFFEY JR.', 'ken griffey jr', 'm', 'False')
# (749, 'Darryl Strawberry', 'darryl strawberry', 'm', 'False')
# (750, 'Hypnotist', 'hypnotist', 'm', 'False')
# (751, 'ALL THE PLAYERS', 'all the players', 'm', 'False')
# (752, 'JOSE CONSECO', 'jose conseco', 'm', 'False')
# (753, 'Ticket Taker', 'ticket taker', 'u', 'False')
# (754, 'Courier', 'courier', 'u', 'False')
# (756, 'FORTE', 'forte', 'u', 'False')
# (757, 'Donna', 'donna', 'f', 'False')
# (758, 'Tammy', 'tammy', 'f', 'False')
# (759, 'PRINCIPAL WILLIE', 'principal willie', 'm', 'False')
# (760, 'Prosecutor', 'prosecutor', 'u', 'False')
# (761, 'Steve Allen', 'steve allen', 'm', 'False')
# (762, 'Mr. Montone', 'mr montone', 'm', 'False')
# (763, 'Former Teacher', 'former teacher', 'u', 'False')
# (764, 'Teacher #1', 'teacher 1', 'u', 'False')
# (765, 'Teacher #2', 'teacher 2', 'u', 'False')
# (766, 'Hippie Teacher', 'hippie teacher', 'm', 'False')
# (767, 'Employee', 'employee', 'm', 'False')
# (768, 'Employer', 'employer', 'u', 'False')
# (769, 'Window Washers', 'window washers', 'u', 'False')
# (770, 'Sanjay Nahasapeemapetilon', 'sanjay nahasapeemapetilon', 'm', 'False')
# (771, 'Lottery Announcer', 'lottery announcer', 'u', 'False')
# (772, 'Vet', 'vet', 'u', 'False')
# (773, 'Mr. Danielson', 'mr danielson', 'm', 'False')
# (774, 'God', 'god', 'm', 'False')
# (775, 'Sadistic Barfly', 'sadistic barfly', 'u', 'False')
# (776, 'Young Barfly', 'young barfly', 'u', 'False')
# (777, 'Trainee', 'trainee', 'u', 'False')
# (778, 'Butler', 'butler', 'u', 'False')
# (779, 'Ticket Man', 'ticket man', 'm', 'False')
# (780, 'General', 'general', 'u', 'False')
# (781, 'Cowboy #1', 'cowboy 1', 'm', 'False')
# (782, 'Cowboy #2', 'cowboy 2', 'm', 'False')
# (783, 'Bar Owner', 'bar owner', 'u', 'False')
# (784, "Yodelin' Zeke", 'yodelin zeke', 'u', 'False')
# (785, 'Lurleen Lumpkin', 'lurleen lumpkin', 'f', 'False')
# (786, 'Male Nurse', 'male nurse', 'm', 'False')
# (787, 'Music Store Owner', 'music store owner', 'u', 'False')
# (788, 'Mr. Boylan', 'mr boylan', 'm', 'False')
# (789, 'Mule', 'mule', 'u', 'False')
# (790, 'Young Girl', 'young girl', 'f', 'False')
# (791, 'Pretty Girl', 'pretty girl', 'f', 'False')
# (792, 'Orville', 'orville', 'm', 'False')
# (793, 'Hurley', 'hurley', 'm', 'False')
# (794, 'Dinosaur Dad', 'dinosaur dad', 'm', 'False')
# (795, 'Dinosaur Son', 'dinosaur son', 'm', 'False')
# (796, 'Cellmate #1', 'cellmate 1', 'u', 'False')
# (797, 'FAMILY/EVERYONE', 'familyeveryone', 'u', 'False')
# (798, 'Crooner', 'crooner', 'u', 'False')
# (799, 'MacGyver', 'macgyver', 'm', 'False')
# (800, 'T-shirt Guy', 't-shirt guy', 'm', 'False')
# (801, 'Comic Book Guy', 'comic book guy', 'm', 'False')
# (802, 'David', 'david', 'm', 'False')
# (803, 'Nigel Bakerbutcher', 'nigel bakerbutcher', 'm', 'False')
# (804, 'DEREK', 'derek', 'm', 'False')
# (805, 'Roadie', 'roadie', 'u', 'False')
# (806, 'Stoned Guy', 'stoned guy', 'm', 'False')
# (807, 'Promoter', 'promoter', 'u', 'False')
# (808, 'DAVID/NIGEL', 'davidnigel', 'm', 'False')
# (809, 'DAVID/NIGEL/DEREK', 'davidnigelderek', 'm', 'False')
# (810, 'Landlord', 'landlord', 'u', 'False')
# (811, 'Samantha Stanky', 'samantha stanky', 'f', 'False')
# (812, 'Grave Digger', 'grave digger', 'u', 'False')
# (813, 'Crane Operator', 'crane operator', 'u', 'False')
# (814, 'Worker #1', 'worker 1', 'u', 'False')
# (815, 'Worker #2', 'worker 2', 'u', 'False')
# (816, 'Mr. Stanky', 'mr stanky', 'm', 'False')
# (817, 'Kirk Van Houten', 'kirk van houten', 'm', 'False')
# (818, 'Nun', 'nun', 'f', 'False')
# (819, 'NUN #2', 'nun 2', 'f', 'False')
# (820, 'Bum', 'bum', 'u', 'False')
# (821, 'WILLIAM POWEL LOOKALIKE', 'william powel lookalike', 'm', 'False')
# (822, 'Bum #2', 'bum 2', 'u', 'False')
# (823, 'Nbc Anchorman', 'nbc anchorman', 'm', 'False')
# (824, 'Jittery Private', 'jittery private', 'u', 'False')
# (825, 'Angry Sergeant', 'angry sergeant', 'u', 'False')
# (826, 'Men Singers', 'men singers', 'm', 'False')
# (827, 'Female Singers', 'female singers', 'f', 'False')
# (828, "Smokin' Joe Frazier", 'smokin joe frazier', 'm', 'False')
# (829, 'Herb Powell', 'herb powell', 'm', 'False')
# (830, 'Mom', 'mom', 'f', 'False')
# (831, 'Teachers', 'teachers', 'u', 'False')
# (832, 'Mr. Black', 'mr black', 'm', 'False')
# (833, 'Sergeant', 'sergeant', 'u', 'False')
# (834, 'Campers', 'campers', 'u', 'False')
# (835, 'Line Judge', 'line judge', 'u', 'False')
# (836, 'Stablehand', 'stablehand', 'u', 'False')
# (837, 'Little Boy #1', 'little boy 1', 'm', 'False')
# (838, 'Queen Elizabeth II', 'queen elizabeth ii', 'f', 'False')
# (839, 'Yoga Instructor', 'yoga instructor', 'u', 'False')
# (840, "HOMER'S THOUGHT", 'homers thought', 'm', 'True')
# (841, 'Contestants', 'contestants', 'u', 'False')
# (842, 'Mr. Bozwell', 'mr bozwell', 'm', 'False')
# (843, 'DEBORAH JO SMALLWOOD', 'deborah jo smallwood', 'f', 'False')
# (844, 'Llewellyn Sinclair', 'llewellyn sinclair', 'm', 'False')
# (845, 'Auditioning Woman #1', 'auditioning woman 1', 'f', 'False')
# (846, 'Auditioning Woman #2', 'auditioning woman 2', 'f', 'False')
# (847, 'Auditioning Woman #3', 'auditioning woman 3', 'f', 'False')
# (848, 'Ms. Sinclair', 'ms sinclair', 'f', 'False')
# (849, 'Video Game Voice', 'video game voice', 'u', 'False')
# (850, 'Company', 'company', 'u', 'False')
# (851, 'Actress', 'actress', 'f', 'False')
# (852, 'Male Parishoner', 'male parishoner', 'm', 'False')
# (853, 'Stooge #1', 'stooge 1', 'u', 'False')
# (854, 'Stooge #2', 'stooge 2', 'u', 'False')
# (855, 'Boring Guy', 'boring guy', 'm', 'False')
# (856, 'Commentator', 'commentator', 'u', 'False')
# (857, 'Abraham Lincoln', 'abraham lincoln', 'm', 'False')
# (858, 'Flanders Family', 'flanders family', 'u', 'False')
# (859, 'Jamshed', 'jamshed', 'u', 'False')
# (860, 'Insurance Agent', 'insurance agent', 'u', 'False')
# (861, 'Barker', 'barker', 'u', 'False')
# (862, 'Booth Man', 'booth man', 'm', 'False')
# (863, 'Caricaturist', 'caricaturist', 'u', 'False')
# (864, 'Small Voice', 'small voice', 'u', 'False')
# (865, 'Tv Father', 'tv father', 'm', 'False')
# (866, 'Tv Daughter', 'tv daughter', 'f', 'False')
# (867, 'Bitsy', 'bitsy', 'f', 'False')
# (868, 'Ramona', 'ramona', 'f', 'False')
# (869, 'Owner', 'owner', 'u', 'False')
# (870, 'Ice Cream Lady', 'ice cream lady', 'f', 'False')
# (871, 'Amber Dempsey', 'amber dempsey', 'f', 'False')
# (872, 'Pahasatira', 'pahasatira', 'f', 'False')
# (873, 'Judges', 'judges', 'u', 'False')
# (874, 'Museum Worker', 'museum worker', 'u', 'False')
# (875, 'Show Announcer', 'show announcer', 'u', 'False')
# (876, 'Bob Hope', 'bob hope', 'm', 'False')
# (877, 'Advance Man', 'advance man', 'm', 'False')
# (878, 'Soldier #1', 'soldier 1', 'm', 'False')
# (879, 'Soldier #2', 'soldier 2', 'u', 'False')
# (880, 'Santa Claus', 'santa claus', 'm', 'False')
# (881, 'Nerd #1', 'nerd 1', 'u', 'False')
# (882, 'Nerd #2', 'nerd 2', 'u', 'False')
# (883, 'Football Player', 'football player', 'm', 'False')
# (884, 'Shopkeeper', 'shopkeeper', 'u', 'False')
# (885, 'Gangster', 'gangster', 'u', 'False')
# (886, 'Repairman', 'repairman', 'u', 'False')
# (887, 'Sailor #1', 'sailor 1', 'u', 'False')
# (888, 'Sailor #2', 'sailor 2', 'u', 'False')
# (889, 'Natives', 'natives', 'u', 'False')
# (890, "'30s Reporter", '30s reporter', 'u', 'False')
# (891, 'Girl Star', 'girl star', 'f', 'False')
# (892, 'Co-pilot', 'co-pilot', 'u', 'False')
# (893, 'Monkey', 'monkey', 'u', 'False')
# (894, 'Faces', 'faces', 'u', 'False')
# (895, 'Zombies', 'zombies', 'u', 'False')
# (896, 'Skinner Zombie', 'skinner zombie', 'm', 'False')
# (897, 'Zombie Krusty', 'zombie krusty', 'm', 'False')
# (898, 'Zombie Flanders', 'zombie flanders', 'm', 'False')
# (899, "Zombie D.J.'s", 'zombie djs', 'u', 'False')
# (900, 'Zombie Shakespeare', 'zombie shakespeare', 'm', 'False')
# (901, 'Lisa Snail', 'lisa snail', 'f', 'True')
# (902, 'Zombie', 'zombie', 'u', 'False')
# (903, 'Pilgrim Zombie', 'pilgrim zombie', 'm', 'False')
# (904, 'Cowboy Zombie', 'cowboy zombie', 'm', 'False')
# (905, 'Helmsman', 'helmsman', 'm', 'False')
# (906, 'Chief Engineer', 'chief engineer', 'u', 'False')
# (907, 'Rowdy Woman', 'rowdy woman', 'f', 'False')
# (908, 'Bumblebee Man', 'bumblebee man', 'm', 'False')
# (909, 'Astronaut', 'astronaut', 'u', 'False')
# (910, 'Booth Attendant', 'booth attendant', 'u', 'False')
# (911, 'MCCLURE', 'mcclure', 'm', 'False')
# (912, 'Contractor', 'contractor', 'u', 'False')
# (913, 'Headless Brakeman', 'headless brakeman', 'm', 'False')
# (914, 'Marley', 'marley', 'm', 'False')
# (915, 'Donut Man', 'donut man', 'm', 'False')
# (916, 'Tom Jones', 'tom jones', 'm', 'False')
# (917, 'Animal Handler', 'animal handler', 'u', 'False')
# (918, 'Homer', 'homer', 'm', 'True')
# (919, 'Hunk', 'hunk', 'm', 'False')
# (920, 'Price', 'price', 'u', 'False')
# (921, 'Laura Powers', 'laura powers', 'f', 'False')
# (923, 'Squeaky-Voiced Teen', 'squeaky-voiced teen', 'm', 'False')
# (924, 'Mrs. Powers', 'mrs powers', 'f', 'False')
# (925, 'Guy #1', 'guy 1', 'm', 'False')
# (926, 'Guy #2', 'guy 2', 'm', 'False')
# (927, 'Chef', 'chef', 'u', 'False')
# (928, 'Waiter #2', 'waiter 2', 'm', 'False')
# (929, 'Old Man', 'old man', 'm', 'False')
# (930, 'Attorney', 'attorney', 'u', 'False')
# (931, 'Mailman', 'mailman', 'm', 'False')
# (932, 'Delivery Boy', 'delivery boy', 'm', 'False')
# (933, 'Fat Foreman', 'fat foreman', 'm', 'False')
# (934, 'Old Woman', 'old woman', 'f', 'False')
# (935, 'RICARDO', 'ricardo', 'm', 'False')
# (936, 'Alan Thicke', 'alan thicke', 'm', 'False')
# (937, 'Adjuster', 'adjuster', 'u', 'False')
# (938, 'Model', 'model', 'u', 'False')
# (939, 'Second Man', 'second man', 'm', 'False')
# (940, 'German Engineer', 'german engineer', 'u', 'False')
# (941, 'Adam West', 'adam west', 'm', 'False')
# (942, 'President Bush', 'president bush', 'm', 'False')
# (943, 'Just Stamp the Ticket Man', 'just stamp the ticket man', 'm', 'False')
# (944, 'Captain Horatio McCallister', 'captain horatio mccallister', 'm', 'False')
# (945, 'Linda Ronstadt', 'linda ronstadt', 'f', 'False')
# (946, 'Teenage Barney', 'teenage barney', 'm', 'False')
# (948, 'Copy Writer', 'copy writer', 'u', 'False')
# (949, 'Cameraman', 'cameraman', 'u', 'False')
# (950, 'Bigfoot', 'bigfoot', 'u', 'False')
# (951, 'Mountain Goat', 'mountain goat', 'u', 'False')
# (952, 'Fruit Vendor', 'fruit vendor', 'u', 'False')
# (953, 'Irish Lady', 'irish lady', 'f', 'False')
# (954, 'Italian Lady', 'italian lady', 'f', 'False')
# (955, 'Talk Show Host', 'talk show host', 'u', 'False')
# (956, 'Sidekick', 'sidekick', 'u', 'False')
# (957, 'Realtor', 'realtor', 'u', 'False')
# (958, 'Ad Man', 'ad man', 'm', 'False')
# (959, 'Female Messenger', 'female messenger', 'f', 'False')
# (960, 'Clown Bed', 'clown bed', 'm', 'False')
# (961, 'Korean Gymnast', 'korean gymnast', 'm', 'False')
# (962, 'Pig', 'pig', 'u', 'False')
# (963, 'Hans Moleman', 'hans moleman', 'm', 'False')
# (964, 'Gas Station Boy', 'gas station boy', 'm', 'False')
# (965, 'Billy', 'billy', 'm', 'False')
# (966, "Homer's Spirit", 'homers spirit', 'm', 'True')
# (967, 'INTERCOM', 'intercom', 'u', 'False')
# (968, 'Reporters', 'reporters', 'u', 'False')
# (969, 'Sunday School Teacher', 'sunday school teacher', 'f', 'False')
# (970, 'VIDEO TAPE NARRATOR', 'video tape narrator', 'u', 'False')
# (971, 'Pumpkin Man', 'pumpkin man', 'm', 'False')
# (972, 'Med Students', 'med students', 'u', 'False')
# (973, 'Handsome Young Man', 'handsome young man', 'm', 'False')
# (974, 'Andre', 'andre', 'm', 'False')
# (975, 'Young Riviera', 'young riviera', 'm', 'False')
# (976, 'Angry Man', 'angry man', 'm', 'False')
# (977, 'Warrior', 'warrior', 'u', 'False')
# (978, 'LANLEY', 'lanley', 'm', 'False')
# (979, 'Truckosaurus', 'truckosaurus', 'u', 'False')
# (980, 'Sebastian Kobb', 'sebastian kobb', 'm', 'False')
# (981, 'Woman With Baby', 'woman with baby', 'f', 'False')
# (982, 'Baby', 'baby', 'u', 'False')
# (983, 'NIMOY', 'nimoy', 'm', 'False')
# (984, 'Engineer #1', 'engineer 1', 'u', 'False')
# (985, 'Haverbrook Man', 'haverbrook man', 'm', 'False')
# (986, 'Bart Anchor', 'bart anchor', 'm', 'True')
# (987, 'Lance Murdock', 'lance murdock', 'm', 'False')
# (988, '2nd Announcer', '2nd announcer', 'u', 'False')
# (989, "Homer's Thought Bubble", 'homers thought bubble', 'm', 'True')
# (990, 'Reverend', 'reverend', 'm', 'False')
# ...
# (6456, 'Fbi Trooper #1', 'fbi trooper 1', 'u', 'False')
# (6457, 'Fbi Trooper #2', 'fbi trooper 2', 'u', 'False')
# (6458, 'Fbi Trooper #3', 'fbi trooper 3', 'u', 'False')
# (6459, 'Criminal #1', 'criminal 1', 'u', 'False')
# (6460, 'Criminal #2', 'criminal 2', 'u', 'False')
# (6461, 'Criminals', 'criminals', 'u', 'False')
# (6462, 'Criminal #3', 'criminal 3', 'u', 'False')
# (6463, 'Gottfrid', 'gottfrid', 'm', 'False')
# (6464, 'Death Metal Lead Singer', 'death metal lead singer', 'u', 'False')
# (6465, 'Judd Apatow', 'judd apatow', 'm', 'False')
# (6466, 'SETH ROGEN', 'seth rogen', 'm', 'False')
# (6467, 'Producers', 'producers', 'u', 'False')
# (6468, 'Federal Judge', 'federal judge', 'u', 'False')
# (6469, 'Producer #1', 'producer 1', 'u', 'False')
# (6470, 'Producer #2', 'producer 2', 'u', 'False')
# (6471, 'Producer #3', 'producer 3', 'u', 'False')
# (6472, 'Producer #4', 'producer 4', 'u', 'False')
# (6473, 'Channing Tatum', 'channing tatum', 'm', 'False')
# (6474, 'GRIM ANNOUNCER', 'grim announcer', 'u', 'False')
# (6475, "Radioactive Man's Thoughts", 'radioactive mans thoughts', 'm', 'False')
# (6476, 'The Fracker', 'the fracker', 'u', 'False')
# (6477, 'Charcoal Briquette', 'charcoal briquette', 'u', 'False')
# (6478, 'Citizen Solar', 'citizen solar', 'u', 'False')
# (6479, 'Wind Lad', 'wind lad', 'u', 'False')
# (6480, 'Petroleus Rex', 'petroleus rex', 'u', 'False')
# (6481, 'Harlan Ellison', 'harlan ellison', 'm', 'False')
# (6482, 'Strawberry', 'strawberry', 'u', 'False')
# (6483, 'Real Stan Lee', 'real stan lee', 'm', 'False')
# (6484, 'Kumiko', 'kumiko', 'f', 'False')
# (6485, 'Jim-jam Bonks', 'jim-jam bonks', 'u', 'False')
# (6486, 'Yutaka', 'yutaka', 'u', 'False')
# (6487, 'Michiko', 'michiko', 'u', 'False')
# (6488, 'Bart Snail', 'bart snail', 'm', 'True')
# (6489, 'Stress Ball', 'stress ball', 'u', 'False')
# (6490, 'Will Lyman', 'will lyman', 'm', 'False')
# (6491, 'Anonymous Expert', 'anonymous expert', 'u', 'False')
# (6492, 'Glasses', 'glasses', 'u', 'False')
# (6493, "Hershey's Kid", 'hersheys kid', 'u', 'False')
# (6494, 'Owl Valentine', 'owl valentine', 'u', 'False')
# (6495, 'Jonesy', 'jonesy', 'm', 'False')
# (6496, 'Dr. Carlock', 'dr carlock', 'u', 'False')
# (6497, 'Rev. Kartawijaya', 'rev kartawijaya', 'm', 'False')
# (6498, 'Devil Kid', 'devil kid', 'u', 'False')
# (6499, 'Kid With Lisp', 'kid with lisp', 'u', 'False')
# (6500, 'Diggs', 'diggs', 'm', 'False')
# (6501, 'FREEDOM', 'freedom', 'u', 'False')
# (6502, "Comic Book Guy's Bird", 'comic book guys bird', 'm', 'False')
# (6503, 'Animated Krusty', 'animated krusty', 'm', 'False')
# (6504, 'Alarmist Narrator', 'alarmist narrator', 'u', 'False')
# (6505, 'Jenny McCarthy', 'jenny mccarthy', 'f', 'False')
# (6506, 'Monsarno Rep', 'monsarno rep', 'u', 'False')
# (6507, 'Researcher', 'researcher', 'u', 'False')
# (6508, 'Teens', 'teens', 'u', 'False')
# (6509, 'Docent', 'docent', 'u', 'False')
# (6510, 'Worker On Ground', 'worker on ground', 'u', 'False')
# (6511, 'Worker On Ladder', 'worker on ladder', 'u', 'False')
# (6512, "Hibbert's Father", 'hibberts father', 'm', 'False')
# (6513, 'City Health Employee', 'city health employee', 'u', 'False')
# (6514, "Old Jewish Man's Late Wife", 'old jewish mans late wife', 'f', 'False')
# (6515, 'Uncle Bill', 'uncle bill', 'm', 'False')
# (6516, 'Bingo Caller', 'bingo caller', 'u', 'False')
# (6517, 'Old Man #1', 'old man 1', 'm', 'False')
# (6518, 'Old Man #2', 'old man 2', 'm', 'False')
# (6519, 'Mildred', 'mildred', 'f', 'False')
# (6520, 'Female Dj', 'female dj', 'f', 'False')
# (6521, 'FEMALE D. J.', 'female d j', 'f', 'False')
# (6522, 'Gang Member', 'gang member', 'u', 'False')
# (6523, 'S.a.t. Prepper #1', 'sat prepper 1', 'u', 'False')
# (6524, 'S.a.t. Prepper #2', 'sat prepper 2', 'u', 'False')
# (6525, 'Crowds', 'crowds', 'u', 'False')
# (6526, 'DAWN', 'dawn', 'f', 'False')
# (6527, 'Speedo Salesman', 'speedo salesman', 'u', 'False')
# (6528, 'Sabine', 'sabine', 'f', 'False')
# (6529, 'KLAUS ZIEGLER', 'klaus ziegler', 'm', 'False')
# (6530, 'Stephen Douglas', 'stephen douglas', 'm', 'False')
# (6531, 'Elderly Japanese Man', 'elderly japanese man', 'm', 'False')
# (6532, 'Ezra', 'ezra', 'm', 'False')
# (6533, 'Federation Executive', 'federation executive', 'u', 'False')
# (6534, 'FEDERATION EXECUTIVE #2', 'federation executive 2', 'u', 'False')
# (6535, 'Brazilian Lady', 'brazilian lady', 'f', 'False')
# (6536, 'Voice From Tablet', 'voice from tablet', 'u', 'False')
# (6537, 'Brazilian Fans', 'brazilian fans', 'u', 'False')
# (6538, 'El Divo', 'el divo', 'u', 'False')
# (6539, 'ANDRES CANTOR', 'andres cantor', 'm', 'False')
# (6540, 'Spanish Announcer', 'spanish announcer', 'u', 'False')
# (6541, 'Antonio', 'antonio', 'm', 'False')
# (6542, '2nd Gambler', '2nd gambler', 'u', 'False')
# (6543, 'Samba Instructor', 'samba instructor', 'u', 'False')
# (6544, 'Man In Robe', 'man in robe', 'm', 'False')
# (6545, 'Drycleaner Guys', 'drycleaner guys', 'm', 'False')
# (6546, 'Brazil Fan', 'brazil fan', 'u', 'False')
# (6547, 'German Fan', 'german fan', 'u', 'False')
# (6548, 'Older German Man', 'older german man', 'm', 'False')
# (6549, 'Brazilians', 'brazilians', 'u', 'False')
# (6550, 'Softball Player', 'softball player', 'u', 'False')
# (6551, 'Body Shop Clerk', 'body shop clerk', 'u', 'False')
# (6552, 'Lucas', 'lucas', 'm', 'False')
# (6553, 'MARGE 7', 'marge 7', 'f', 'True')
# (6554, 'Adult Lucas', 'adult lucas', 'm', 'False')
# (6555, 'JERRY', 'jerry', 'm', 'False')
# (6556, 'Adult Jenda', 'adult jenda', 'f', 'False')
# (6557, 'DINOSAUR TRAINER', 'dinosaur trainer', 'u', 'False')
# (6558, 'ZOMBIE MILHOUSE', 'zombie milhouse', 'm', 'False')
# (6559, 'BRUNETTE', 'brunette', 'f', 'False')
# (6560, 'Alien Woman', 'alien woman', 'f', 'False')
# (6561, 'Adult Dolph', 'adult dolph', 'm', 'False')
# (6562, 'CHIEF RALPH', 'chief ralph', 'm', 'False')
# (6563, 'PICARD', 'picard', 'm', 'False')
# (6564, 'Adult Maggie', 'adult maggie', 'f', 'True')
# (6565, "SANTA'S LITTLE HYBRID", 'santas little hybrid', 'u', 'False')
# (6566, 'SELF-DRIVING CAR', 'self-driving car', 'u', 'False')
# (6567, 'Bartenders', 'bartenders', 'u', 'False')
# (6568, 'Hispanic Guy In Truck', 'hispanic guy in truck', 'm', 'False')
# (6569, 'Mrs. Trunch', 'mrs trunch', 'f', 'False')
# (6570, 'Haitian Woman', 'haitian woman', 'f', 'False')
# (6571, '20-something Wife', '20-something wife', 'f', 'False')
# (6572, '20-something Husband', '20-something husband', 'm', 'False')
# (6573, '12-Year-Old Homer', '12-year-old homer', 'm', 'True')
# (6574, 'Cats', 'cats', 'u', 'False')
# (6575, 'BRITISH MAN', 'british man', 'm', 'False')
# (6576, 'Booth', 'booth', 'u', 'False')
# (6577, 'Snooty Judge', 'snooty judge', 'u', 'False')
# (6578, 'Cathy', 'cathy', 'f', 'False')
# (6579, 'Wallis', 'wallis', 'u', 'False')
# (6580, 'WISEGUY BOY', 'wiseguy boy', 'm', 'False')
# (6581, 'GUS HUEBNER', 'gus huebner', 'm', 'False')
# (6582, 'Tumi', 'tumi', 'u', 'False')
# (6583, 'Peter Sagal', 'peter sagal', 'm', 'False')
# (6584, 'Carl Kasell', 'carl kasell', 'm', 'False')
# (6585, 'Minority Whip', 'minority whip', 'u', 'False')
# (6586, 'Mean Girl', 'mean girl', 'f', 'False')
# (6587, 'Edwin Moses', 'edwin moses', 'm', 'False')
# (6588, 'Super Milhouse', 'super milhouse', 'm', 'False')
# (6589, 'Lisping Boy', 'lisping boy', 'm', 'False')
# (6590, 'Cassidy The Crocodile', 'cassidy the crocodile', 'u', 'False')
# (6591, 'Henrietta Kitten', 'henrietta kitten', 'f', 'False')
# (6592, "KRUSTY'S HEAD", 'krustys head', 'u', 'False')
# (6593, 'JEFF ROSS', 'jeff ross', 'm', 'False')
# (6594, 'SARAH SILVERMAN', 'sarah silverman', 'f', 'False')
# (6595, 'RABBIS', 'rabbis', 'm', 'False')
# (6596, 'RABBI RUDENSTEIN', 'rabbi rudenstein', 'm', 'False')
# (6597, 'TEENAGED KRUSTY', 'teenaged krusty', 'm', 'False')
# (6598, 'CLIVE MERIWETHER', 'clive meriwether', 'm', 'False')
# (6599, 'DAVID HYDE PIERCE', 'david hyde pierce', 'm', 'False')
# (6600, 'NEIL SIMON', 'neil simon', 'm', 'False')
# (6601, 'MIDDLE-AGED KRUSTY', 'middle-aged krusty', 'm', 'False')
# (6602, 'GERMAN HOUSEKEEPER', 'german housekeeper', 'u', 'False')
# (6603, 'RODNEY DANGERFIELD', 'rodney dangerfield', 'm', 'False')
# (6604, 'RESUSCI-ANNIE', 'resusci-annie', 'u', 'False')
# (6605, 'CEELO GREEN-TYPE', 'ceelo green-type', 'm', 'False')
# (6606, 'CAPTAIN BOWDITCH', 'captain bowditch', 'm', 'False')
# (6607, 'GITMO', 'gitmo', 'u', 'False')
# (6608, 'NFL NARRATOR', 'nfl narrator', 'm', 'False')
# (6609, 'CAPTAIN BOWDITCH/SAILORS', 'captain bowditchsailors', 'u', 'False')
# (6610, 'TRUDY ZENGLER', 'trudy zengler', 'f', 'False')
# (6611, 'KID DEMON', 'kid demon', 'u', 'False')
# (6612, 'BULLY DEMON', 'bully demon', 'u', 'False')
# (6613, 'SCREAMING TORSO', 'screaming torso', 'u', 'False')
# (6614, 'DEMON GIRL', 'demon girl', 'f', 'False')
# (6615, 'PRINCIPAL HEAD #2', 'principal head 2', 'u', 'False')
# (6616, 'DEMON TEACHER', 'demon teacher', 'u', 'False')
# (6617, 'JEFFISTOPHELES', 'jeffistopheles', 'u', 'False')
# (6618, 'JOCK DEMON', 'jock demon', 'u', 'False')
# (6619, 'HOT STUFF', 'hot stuff', 'u', 'False')
# (6620, 'PRINCIPAL HEAD #1', 'principal head 1', 'u', 'False')
# (6621, 'NOAH WEBSTER', 'noah webster', 'm', 'False')
# (6622, 'MISERABLE MAN', 'miserable man', 'm', 'False')
# (6623, 'MOOG', 'moog', 'm', 'False')
# (6624, 'WISEGUYS', 'wiseguys', 'm', 'False')
# (6625, 'MOOG/LEONARD/CARLTON/DUM', 'moogleonardcarltondum', 'u', 'False')
# (6626, 'DUM', 'dum', 'u', 'False')
# (6627, 'LEONARD/CARLTON', 'leonardcarlton', 'm', 'False')
# (6628, 'PARTYGOER', 'partygoer', 'u', 'False')
# (6629, 'STANLEY KUBRICK', 'stanley kubrick', 'm', 'False')
# (6630, 'AL BUNDY', 'al bundy', 'm', 'False')
# (6631, 'PEG ALIEN', 'peg alien', 'f', 'False')
# (6632, 'ORIGINAL MARGE', 'original marge', 'f', 'True')
# (6633, 'ORIGINAL HOMER', 'original homer', 'm', 'True')
# (6634, 'ORIGINAL BART', 'original bart', 'm', 'True')
# (6635, 'REGULAR GHOST MARGE', 'regular ghost marge', 'f', 'True')
# (6636, 'REGULAR GHOST LISA', 'regular ghost lisa', 'f', 'True')
# (6637, 'REGULAR GHOST HOMER', 'regular ghost homer', 'm', 'True')
# (6638, 'ORIGINAL GHOST MARGE', 'original ghost marge', 'f', 'True')
# (6639, 'REGULAR GHOST MARGE/ ORIGINAL GHOST MARGE', 'regular ghost marge original ghost marge', 'f', 'True')
# (6640, 'ORIGINAL GHOST BART', 'original ghost bart', 'm', 'True')
# (6641, 'ORIGINAL GHOST HOMER', 'original ghost homer', 'm', 'True')
# (6642, 'CGI HOMER', 'cgi homer', 'm', 'True')
# (6643, 'CGI DOG', 'cgi dog', 'u', 'False')
# (6644, 'MINION MARGE SIMPSON', 'minion marge simpson', 'f', 'True')
# (6645, 'MINION HOMER SIMPSON', 'minion homer simpson', 'm', 'True')
# (6646, 'ORIGINAL GHOST LISA', 'original ghost lisa', 'f', 'True')
# (6647, 'MAXINE LOMBARD', 'maxine lombard', 'f', 'False')
# (6648, 'MUTANT CHARLIE', 'mutant charlie', 'm', 'False')
# (6649, 'MAXINE', 'maxine', 'f', 'False')
# (6650, 'HEDONISMBOT', 'hedonismbot', 'u', 'False')
# (6651, 'JUKEBOX RECORD', 'jukebox record', 'u', 'False')
# (6652, 'LEELA', 'leela', 'f', 'False')
# (6653, 'FRY', 'fry', 'm', 'False')
# (6654, 'PROFESSOR FARNSWORTH', 'professor farnsworth', 'm', 'False')
# (6655, 'HERMES', 'hermes', 'm', 'False')
# (6656, 'DR. ZOIDBERG', 'dr zoidberg', 'm', 'False')
# (6657, 'FRY/PROFESSOR/LEELA', 'fryprofessorleela', 'u', 'False')
# (6658, 'MORBO', 'morbo', 'u', 'False')
# (6659, 'LINDA', 'linda', 'f', 'False')
# (6660, 'BART GOBLINS', 'bart goblins', 'm', 'True')
# (6661, 'SCRUFFY', 'scruffy', 'u', 'False')
# (6662, 'SPOILED 2-YEAR-OLD', 'spoiled 2-year-old', 'u', 'False')
# (6663, 'LRRR', 'lrrr', 'u', 'False')
# (6664, 'NDND', 'ndnd', 'u', 'False')
# (6665, 'TEACHER IN BACK', 'teacher in back', 'u', 'False')
# (6666, 'MR. LASSEN', 'mr lassen', 'm', 'False')
# (6667, 'DESERT HIPSTER', 'desert hipster', 'u', 'False')
# (6668, 'CUPCAKE MAN', 'cupcake man', 'm', 'False')
# (6669, 'BLAZING GUY VETERAN', 'blazing guy veteran', 'm', 'False')
# (6670, 'HIPSTER WOMAN', 'hipster woman', 'f', 'False')
# (6671, 'TUBA PLAYER', 'tuba player', 'u', 'False')
# (6672, 'BLAZING GUY HIPSTER', 'blazing guy hipster', 'm', 'False')
# (6673, 'FIRE PRIESTESS', 'fire priestess', 'm', 'False')
# (6674, '2ND REVELER', '2nd reveler', 'u', 'False')
# (6675, 'MAN IN CENTER OF PRISON', 'man in center of prison', 'm', 'False')
# (6676, 'NELSON COMET', 'nelson comet', 'm', 'False')
# (6677, 'KING TOOT', 'king toot', 'm', 'False')
# (6678, 'GUITAR CENTRAL EMPLOYEE #1', 'guitar central employee 1', 'u', 'False')
# (6679, 'STIG', 'stig', 'u', 'False')
# (6680, 'SUNGAZER SINGER', 'sungazer singer', 'u', 'False')
# (6681, 'NICK DELACOURT', 'nick delacourt', 'm', 'False')
# (6682, "PETER D'ABBRUZIO", 'peter dabbruzio', 'm', 'False')
# (6683, 'SHREDDER STEVENS', 'shredder stevens', 'm', 'False')
# (6684, 'LORDS OF ROCK', 'lords of rock', 'u', 'False')
# (6685, 'SAMMY HAGAR', 'sammy hagar', 'm', 'False')
# (6686, 'FREDDY FREEMAN', 'freddy freeman', 'm', 'False')
# (6687, 'FORUM ANNOUNCER', 'forum announcer', 'u', 'False')
# (6688, 'COVERCRAFT', 'covercraft', 'u', 'False')
# (6689, 'R3', 'r3', 'u', 'False')
# (6690, 'GOLDEN ROBOT', 'golden robot', 'u', 'False')
# (6691, 'KARAOKE MACHINE', 'karaoke machine', 'u', 'False')
# (6692, 'WISEGUY VENDOR', 'wiseguy vendor', 'm', 'False')
# (6693, 'BLUE', 'blue', 'u', 'False')
# (6694, 'NUTCRACKER', 'nutcracker', 'u', 'False')
# (6695, 'SCARECROW', 'scarecrow', 'u', 'False')
# (6696, 'ITALIAN FATHER', 'italian father', 'm', 'False')
# (6697, 'WISE ELDERLY ALIEN', 'wise elderly alien', 'u', 'False')
# (6698, 'PIRATES', 'pirates', 'u', 'False')
# (6699, 'MANIC MOUSE', 'manic mouse', 'u', 'False')
# (6700, 'COOL ZONE RECORDING', 'cool zone recording', 'u', 'False')
# (6701, 'PARKGOERS', 'parkgoers', 'u', 'False')
# (6702, 'ALIEN PORN STAR/FEMALE ALIEN PORN STAR', 'alien porn starfemale alien porn star', 'f', 'False')
# (6703, 'FLYING SQUIRREL', 'flying squirrel', 'u', 'False')
# (6704, 'ALIEN ATTORNEY', 'alien attorney', 'u', 'False')
# (6705, 'BAGPIPER', 'bagpiper', 'u', 'False')
# (6706, 'ALIEN MOM', 'alien mom', 'f', 'False')
# (6707, 'ALIEN MOM/ALIEN KIDS', 'alien momalien kids', 'u', 'False')
# (6708, 'YOUNG FEMALE CREATURE', 'young female creature', 'f', 'False')
# (6709, 'INTELLECTUAL ALIEN', 'intellectual alien', 'u', 'False')
# (6710, 'ALIEN ANNOUNCER #1', 'alien announcer 1', 'u', 'False')
# (6711, 'KLAUNAX', 'klaunax', 'u', 'False')
# (6712, 'SWEET MALE VOICES', 'sweet male voices', 'm', 'False')
# (6713, 'GENTLE VOICE', 'gentle voice', 'u', 'False')
# (6714, 'ALIEN MAN', 'alien man', 'm', 'False')
# (6715, 'SPACE BROCCOLI', 'space broccoli', 'u', 'False')
# (6716, 'DON BOOKNER', 'don bookner', 'm', 'False')
# (6717, 'CIRCUS AUDIENCE', 'circus audience', 'u', 'False')
# (6718, 'FINGERNAIL MAN', 'fingernail man', 'm', 'False')
# (6719, 'SVEN-GOLLY', 'sven-golly', 'm', 'False')
# (6720, 'ELON MUSK', 'elon musk', 'm', 'False')
# (6721, 'ELON', 'elon', 'm', 'False')
# (6722, 'IMAGINER', 'imaginer', 'u', 'False')
# (6723, 'YOUNG JEWISH MAN', 'young jewish man', 'm', 'False')
# (6724, 'YOUNG MOLEMAN', 'young moleman', 'm', 'False')
# (6725, 'TUSCALOOSA PEOPLE', 'tuscaloosa people', 'u', 'False')
# (6726, 'PHARRELL WILLIAMS', 'pharrell williams', 'm', 'False')
# (6727, 'PRIDESTERS', 'pridesters', 'u', 'False')
# (6728, 'ALBERT', 'albert', 'm', 'False')
# (6729, 'LANEY FONTAINE', 'laney fontaine', 'u', 'False')
# (6730, 'LADY DUFF', 'lady duff', 'f', 'False')
# (6731, 'BOOK CLUB MEMBER', 'book club member', 'u', 'False')
# (6732, 'OTHER BOOK CLUB MEMBER', 'other book club member', 'u', 'False')
# (6733, 'HEAD INSPECTOR', 'head inspector', 'u', 'False')
# (6734, 'SIKH CAB DRIVER', 'sikh cab driver', 'u', 'False')
# (6735, 'JIM IGNATOWSKI', 'jim ignatowski', 'u', 'False')
# (6736, 'CHAPIN-LIKE SINGER', 'chapin-like singer', 'u', 'False')
# (6737, 'HARRY CHAPIN-TYPE SINGER', 'harry chapin-type singer', 'm', 'False')
# (6738, 'CABBIES', 'cabbies', 'u', 'False')
# (6739, 'SMILE', 'smile', 'u', 'False')
# (6740, 'KEMI', 'kemi', 'u', 'False')
# (6741, 'PEDICAB DRIVER', 'pedicab driver', 'u', 'False')
# (6742, "SMITHERS' THOUGHTS", 'smithers thoughts', 'm', 'False')
# (6743, 'AGED MOE', 'aged moe', 'm', 'False')
# (6744, 'RICHARD BRANSON', 'richard branson', 'm', 'False')
# (6745, 'CHURCH GROUP', 'church group', 'u', 'False')
# (6746, 'COCKTAIL WAITRESSES', 'cocktail waitresses', 'f', 'False')
# (6747, 'SECURITY THUG #1', 'security thug 1', 'u', 'False')
# (6748, 'SECURITY THUG #2', 'security thug 2', 'u', 'False')
# (6749, 'LATINO WORKERS', 'latino workers', 'u', 'False')

# %%
# Declare a Base using `automap_base()`
Base = automap_base()
# Use the Base class to reflect the database tables
Base.prepare(engine, reflect=True)
# Print all of the classes mapped to the Base
Base.metadata
# Out:
# MetaData(bind=None)
