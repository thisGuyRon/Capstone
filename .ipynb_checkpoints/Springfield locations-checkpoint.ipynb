# %%
# Dependencies
import requests
import json
# SQL Alchemy
from sqlalchemy import create_engine
import pandas as pd
import matplotlib.pyplot as plt
# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()
gkey="AIzaSyDQz8ryxwMD171O6JLsyxYEOGsIMMWb4s4"

# %%
#connection to database
engine = create_engine("mysql://root:Primavera01@localhost/simpsons")
conn = engine.connect()

# %%
#pull current springfield dataset
spring_df = pd.read_sql('select * from springfield', conn)
spring_df
# Out:
#     ﻿id         city           state   country
# 0     1  Springfield         Alabama       USA
# 1     2  Springfield        Arkansas       USA
# 2     3  Springfield      California       USA
# 3     4  Springfield        Colorado       USA
# 4     5  Springfield         Florida       USA
# 5     6  Springfield         Georgia       USA
# 6     7  Springfield           Idaho       USA
# 7     8  Springfield        Illinois       USA
# 8     9  Springfield         Indiana       USA
# 9    10  Springfield        Kentucky       USA
# 10   11  Springfield       Louisiana       USA
# 11   12  Springfield           Maine       USA
# 12   13  Springfield        Maryland       USA
# 13   14  Springfield   Massachusetts       USA
# 14   15  Springfield        Michigan       USA
# 15   16  Springfield       Minnesota       USA
# 16   17  Springfield        Missouri       USA
# 17   18  Springfield        Nebraska       USA
# 18   19  Springfield   New Hampshire       USA
# ...

# %%
#get initial mappings for looping later
target_city="Springfield, Arkansas"
target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&key={1}').format(target_city, gkey)
geo_data = requests.get(target_url).json()
print(geo_data["results"][0]["address_components"][0]["long_name"])
print(geo_data["results"][0]["address_components"][2]["long_name"])
print(geo_data["results"][0]["address_components"][3]["long_name"])
print(geo_data["results"][0]["geometry"]["location"]["lat"])
print(geo_data["results"][0]["geometry"]["location"]["lng"])
geo_data
# Out:
# Springfield
# Conway County
# Arkansas
# 35.2675809
# -92.5576595
# {'results': [{'address_components': [{'long_name': 'Springfield',
#      'short_name': 'Springfield',
#      'types': ['locality', 'political']},
#     {'long_name': 'Union Township',
#      'short_name': 'Union Township',
#      'types': ['administrative_area_level_3', 'political']},
#     {'long_name': 'Conway County',
#      'short_name': 'Conway County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Arkansas',
#      'short_name': 'AR',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '72157', 'short_name': '72157', 'types': ['postal_code']}],
#    'formatted_address': 'Springfield, AR 72157, USA',
#    'geometry': {'location': {'lat': 35.2675809, 'lng': -92.5576595},
#     'location_type': 'APPROXIMATE',
# ...

# %%
#list and dictionary for storage of updated data
springfield=[]
spring_dict={}
#loop through dataframe to store data in dictionary, list
for index, row in spring_df.iterrows():
    target_city=row["city"]+ ", "+row["state"]
    
    target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&key={1}').format(target_city, gkey)
    geo_data = requests.get(target_url).json()
    spring_dict={"city": row["city"], "state": row["state"], "country": row["country"], "lat": geo_data["results"][0]["geometry"]["location"]["lat"], "lng": geo_data["results"][0]["geometry"]["location"]["lng"]}
    springfield.append(spring_dict)

# %%
#convert to dataframe and export to csv to load as new database table
springfield_df = pd.DataFrame(springfield)
springfield_df.to_csv("data/spring_new.csv")
